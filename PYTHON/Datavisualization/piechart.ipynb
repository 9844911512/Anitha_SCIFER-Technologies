# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x=np.array([10,30,20,50,60])

# %%
plt.title("pie")
# Out:
# Text(0.5, 1.0, 'pie')

# %%
mylabel=(["apple","banana","orange","guava","mango"])

# %%
myexplode=([0,0.2,0,0,0])

# %%
plt.pie(x,labels=mylabel,startangle=90,explode=myexplode)
# Out:
# ([<matplotlib.patches.Wedge at 0x1f120505250>,
# ...
#  [Text(-0.2021244703426086, 1.0812704095131431, 'apple'),
#   Text(-1.0374224073296787, 0.7834250115807474, 'banana'),
#   Text(-1.0580081983716194, -0.3010293211274279, 'orange'),
#   Text(7.724207457870327e-08, -1.0999999999999974, 'guava'),
#   Text(0.9846795536563285, 0.49031232557541704, 'mango')])
