# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x=np.array([0,10])

# %%
y=np.array([5,20])

# %%
plt.plot(x,y,ls=':',lw='2',c='b')

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x1=np.array([10,20])

# %%
x2=np.array([1,10])

# %%
y1=np.array([0,15])

# %%
y2=np.array([1,20])

# %%
plt.grid()

# %%
plt.plot(x1,x2,y1,y2)
# Out:
# [<matplotlib.lines.Line2D at 0x1ac950d2910>,
#  <matplotlib.lines.Line2D at 0x1ac950d0250>]
