# %%
import pandas as pd

# %%
import numpy as np

# %%
data={ "name":['ani','dhw','haar'],
                  "age":[35,8,1],
                  "gender":['f','f','m'],
                  "rel":['m','d','s']}
print(data)
# Out:
# {'name': ['ani', 'dhw', 'haar'], 'age': [35, 8, 1], 'gender': ['f', 'f', 'm'], 'rel': ['m', 'd', 's']}

# %%
pd.DataFrame(data)
# Out:
#    name  age gender rel
# 0   ani   35      f   m
# 1   dhw    8      f   d
# 2  haar    1      m   s

# %%
type(data)
# Out:
# dict

# %%
stu_df=pd.DataFrame(data)

# %%
print(stu_df)
# Out:
#    name  age gender rel
# 0   ani   35      f   m
# 1   dhw    8      f   d
# 2  haar    1      m   s

# %%
type(stu_df)
# Out:
# pandas.core.frame.DataFrame

# %%
stu_df.to_csv('student.csv')

# %%
type(student.csv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-72c7fc2dc553> in <cell line: 1>()
# ----> 1 type(student.csv)
#
# NameError: name 'student' is not defined

# %%
df=pd.read_csv("/content/student.csv")

# %%
print(df)
# Out:
#    Unnamed: 0  name  age gender rel
# 0           0   ani   35      f   m
# 1           1   dhw    8      f   d
# 2           2  haar    1      m   s

# %%
df=pd.DataFrame(np.random.rand(20,5))

# %%
print(df)
# Out:
#            0         1         2         3         4
# 0   0.367491  0.257872  0.657655  0.584033  0.512088
# 1   0.425689  0.516879  0.421524  0.823299  0.683198
# 2   0.786087  0.077668  0.958542  0.316227  0.061599
# 3   0.033909  0.220941  0.046439  0.498802  0.617347
# 4   0.214484  0.747601  0.774696  0.491216  0.713550
# 5   0.911687  0.587410  0.942594  0.648999  0.113866
# 6   0.565497  0.680303  0.964526  0.596222  0.622428
# 7   0.924575  0.335181  0.321659  0.217559  0.181286
# 8   0.259994  0.068960  0.558262  0.653945  0.504334
# 9   0.389271  0.265406  0.311590  0.716717  0.888403
# 10  0.517866  0.207392  0.490067  0.256719  0.605144
# 11  0.335768  0.326967  0.654626  0.753660  0.617353
# 12  0.737582  0.301782  0.462820  0.484796  0.982971
# 13  0.510858  0.454532  0.273978  0.819826  0.619413
# 14  0.642278  0.128784  0.701466  0.470748  0.531154
# 15  0.313237  0.305434  0.680454  0.321523  0.953214
# 16  0.941935  0.951193  0.566975  0.870400  0.706498
# ...

# %%
df.head()
# Out:
#           0         1         2         3         4
# 0  0.367491  0.257872  0.657655  0.584033  0.512088
# 1  0.425689  0.516879  0.421524  0.823299  0.683198
# 2  0.786087  0.077668  0.958542  0.316227  0.061599
# 3  0.033909  0.220941  0.046439  0.498802  0.617347
# 4  0.214484  0.747601  0.774696  0.491216  0.713550

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-0e566b70f572> in <cell line: 1>()
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (20, 5)

# %%
tips_df=pd.read_csv('tips.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-c522f8d2a635> in <cell line: 1>()
# ----> 1 tips_df=pd.read_csv('tips.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
tips_df=pd.read_csv('/content/tips.csv')

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips_df.shape
# Out:
# (244, 7)

# %%
tips_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
tips_df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
tips_df.value_counts('smoker')
# Out:
# smoker
# No     151
# Yes     93
# dtype: int64

# %%
tips_df.value_counts('sex')
# Out:
# sex
# Male      157
# Female     87
# dtype: int64

# %%
tips_df.groupby('smoker').mean()
# Out:
# <ipython-input-44-2a32c81a6e98>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tips_df.groupby('smoker').mean()
#         total_bill       tip      size
# smoker
# No       19.188278  2.991854  2.668874
# Yes      20.756344  3.008710  2.408602

# %%
tips_df.count()
# Out:
# total_bill    244
# tip           244
# sex           244
# smoker        244
# day           244
# time          244
# size          244
# dtype: int64

# %%
tips_df.mean()
# Out:
# <ipython-input-46-5bb88463b5dc>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tips_df.mean()
# total_bill    19.785943
# tip            2.998279
# size           2.569672
# dtype: float64

# %%
tips_df.std()
# Out:
# <ipython-input-47-1625010bfc23>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tips_df.std()
# total_bill    8.902412
# tip           1.383638
# size          0.951100
# dtype: float64

# %%
tips_df.min()
# Out:
# total_bill      3.07
# tip              1.0
# sex           Female
# smoker            No
# day              Fri
# time          Dinner
# size               1
# dtype: object

# %%
tips_df.max()
# Out:
# total_bill    50.81
# tip            10.0
# sex            Male
# smoker          Yes
# day            Thur
# time          Lunch
# size              6
# dtype: object

# %%
tips_df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_df.drop(index=1,axis=0)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [243 rows x 7 columns]

# %%
tips_df.drop(columns='day',axis=1)
# Out:
#      total_bill   tip     sex smoker    time  size
# 0         16.99  1.01  Female     No  Dinner     2
# 1         10.34  1.66    Male     No  Dinner     3
# 2         21.01  3.50    Male     No  Dinner     3
# 3         23.68  3.31    Male     No  Dinner     2
# 4         24.59  3.61  Female     No  Dinner     4
# ..          ...   ...     ...    ...     ...   ...
# 239       29.03  5.92    Male     No  Dinner     3
# 240       27.18  2.00  Female    Yes  Dinner     2
# 241       22.67  2.00    Male    Yes  Dinner     2
# 242       17.82  1.75    Male     No  Dinner     2
# 243       18.78  3.00  Female     No  Dinner     2
#
# [244 rows x 6 columns]

# %%
tips_df.iloc[3]
# Out:
# total_bill     23.68
# tip             3.31
# sex             Male
# smoker            No
# day              Sun
# time          Dinner
# size               2
# Name: 3, dtype: object

# %%
print(tips_df.iloc[:,1])
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
tips_df.corr()
# Out:
# <ipython-input-59-31b1ca03d81d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tips_df.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000
